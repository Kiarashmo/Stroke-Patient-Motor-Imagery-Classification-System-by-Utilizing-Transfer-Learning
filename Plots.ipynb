 0.5333333611488342, 0.5333333611488342, 0.5333333611488342, 0.6000000238418579]



### Subject Specific
tl_ss_train = [0.4375, 0.5416666865348816, 0.8125, 0.5625, 0.9166666865348816, 0.8958333134651184, 0.9375, 0.9375, 0.6875, 0.7291666865348816, 0.75, 0.8958333134651184, 0.7916666865348816, 0.6666666865348816, 0.5833333134651184, 0.8541666865348816, 0.5625, 0.8333333134651184, 0.6041666865348816, 0.5208333134651184, 0.8958333134651184, 0.9791666865348816, 0.9166666865348816, 0.6041666865348816, 0.7083333134651184, 0.8541666865348816, 0.9375, 0.5, 1.0, 0.9583333134651184, 0.5833333134651184, 0.5, 0.8333333134651184, 0.9166666865348816, 0.8333333134651184, 0.5416666865348816, 0.5208333134651184, 0.8125, 0.8541666865348816, 0.8958333134651184, 0.5625, 0.8541666865348816, 0.9375, 0.4583333432674408, 0.625, 0.5416666865348816, 0.625, 1.0, 0.5625, 0.6666666865348816]
tl_ss_val = [0.6875, 0.3125, 0.4375, 0.375, 0.4375, 0.3125, 0.75, 0.75, 0.4375, 0.5625, 0.5, 0.6875, 0.5, 0.4375, 0.4375, 0.4375, 0.5625, 0.75, 0.4375, 0.375, 0.5, 0.6875, 0.5, 0.75, 0.75, 0.4375, 0.625, 0.375, 0.5, 0.4375, 0.5, 0.5, 0.4375, 0.625, 0.5625, 0.625, 0.625, 0.5, 0.625, 0.5625, 0.4375, 0.375, 0.4375, 0.75, 0.5625, 0.5625, 0.625, 0.6875, 0.4375, 0.375]
tl_ss_test = [0.5333333611488342, 0.6000000238418579, 0.6666666865348816, 0.5333333611488342, 0.46666666865348816, 0.4000000059604645, 0.7333333492279053, 0.800000011920929, 0.4000000059604645, 0.46666666865348816, 0.5333333611488342, 0.46666666865348816, 0.6000000238418579, 0.4000000059604645, 0.6666666865348816, 0.46666666865348816, 0.46666666865348816, 0.5333333611488342, 0.6000000238418579, 0.6000000238418579, 0.5333333611488342, 0.800000011920929, 0.46666666865348816, 0.46666666865348816, 0.7333333492279053, 0.46666666865348816, 0.6000000238418579, 0.6000000238418579, 0.46666666865348816, 0.9333333373069763, 0.46666666865348816, 0.5333333611488342, 0.46666666865348816, 0.800000011920929, 0.800000011920929, 0.3333333432674408, 0.46666666865348816, 0.4000000059604645, 0.5333333611488342, 0.6666666865348816, 0.4000000059604645, 0.5333333611488342, 0.5333333611488342, 0.5333333611488342, 0.6000000238418579, 0.6000000238418579, 0.3333333432674408, 0.6000000238418579, 0.4000000059604645, 0.7333333492279053]

# %%
import numpy as np

# %%
def avg(accs):
  return round(np.average(accs) * 100, 1)

# %%
print(avg(base_all_test))
print(avg(base_ss_test))
print(avg(tl_all_test))
print(avg(tl_ss_test))
# Out:
# 47.2
# 48.9
# 49.7
# 55.5

# %%
import matplotlib.pyplot as plt

chance_level = 0.5 * np.ones((50,1))
# average_level = average * np.ones((50,1))

subj = np.arange(1, len(tl_ss_test)+1)

plt.figure(figsize=(15,4))

plt.bar(subj+0.1, base_ss_test, 0.5, label = 'No TL', color="#b3e6ff")
plt.bar(subj-0.2, tl_ss_test,0.5, label = 'TL', color="#4ba173ff")

plt.plot(subj, chance_level , '-', color="black", label="Chance Level")
plt.plot(subj, avg(base_ss_test) / 100 * np.ones((50,1)), '--', color="#0099e6", label="No TL avg")
plt.plot(subj, avg(tl_ss_test) / 100 * np.ones((50,1)), '--', color="#397957", label="TL avg")

plt.title(f'Model Accuracy on Test Set for Each Subject')
plt.xlabel('Subject')
plt.xticks(subj)
plt.ylabel('Accuracy')
plt.legend()
plt.xticks(rotation=90)
# plt.savefig(name)
plt.show()
